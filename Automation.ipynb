# %% [markdown]
# # Library

# %%
import pandas as pd

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Read Csv from URL

# %% [markdown]
# Target Website: https://www.football-data.co.uk/data.php

# %%
df= pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv")

# %%
df.rename(columns={"FTHG":"Home Goal",
                  "FTAG":"Away Goal"
                  })
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  Home Goal  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal          2
# 1    E0  14/08/2021  12:30      Man United           Leeds          5
# 2    E0  14/08/2021  15:00         Burnley        Brighton          1
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace          3
# 4    E0  14/08/2021  15:00         Everton     Southampton          3
# ..   ..         ...    ...             ...             ...        ...
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United          1
# 376  E0  22/05/2022  16:00       Leicester     Southampton          4
# 377  E0  22/05/2022  16:00       Liverpool          Wolves          3
# 378  E0  22/05/2022  16:00        Man City     Aston Villa          3
# 379  E0  22/05/2022  16:00         Norwich       Tottenham          0
#
#      Away Goal FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  \
# ...

# %% [markdown]
# ## extract table from pdf

# %% [markdown]
# import camelot

# %% [markdown]
# # HTML

# %% [markdown]
# ## Web Automation & Web Scraping - HTML Basics - Tags and Elements

# %% [raw]
# <h1 class="Title"> Titanic (1997) </h1>

# %% [raw]
# <head>
# <body>
# <header>
# <article>
# <p>; paragraph
# <h1><h2><h3> ; level heading

# %% [raw]
# <div>: divider
# <nav>: navigattional
# <li>:list item
# <a>: anchor
#  <a href="https//exampple.com">Text </a>

# %% [raw]
# *forms*
#
# <button>
# <table>
# <td>: table data element
# <tr>: table row element
# <ul>: unordered list
# <iframe>

# %%
from IPython.display import Image
Image(filename="WechatIMG12157.jpeg")

# %% [markdown]
# ## Web Automation & Web Scraping - XPath - Syntax, Functions and Operators

# %% [raw]
# //tagname[@AttributeName,"Value"]
# contain()
# (expresssion1) and (expression2)

# %% [raw]
# ./: selection the children node, on the left side
# .. : parent node
# * : select all attribute regardless of name
# @ : select a attribut
# ()
# [n]: index
